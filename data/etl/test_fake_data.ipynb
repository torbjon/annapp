# %%
import pandas as pd
import xml.etree.ElementTree as ET
import datetime as dt
import numpy as np

# %%
# Passing the path of the
# xml document to enable the
# parsing process
tree = ET.parse("wearable_data/apple_health_export/export.xml")

# getting the parent tag of
# the xml document
root = tree.getroot()

# printing the root (parent) tag
# of the xml document, along with
# its memory location
print(root)

# printing the attributes of the
# first tag from the parent 
print(root[0].attrib)
# Out:
# <Element 'HealthData' at 0x1112f06d0>
# {'value': '2025-10-27 12:40:27 +0200'}

# %%
record_list = [x.attrib for x in root.iter('Record')]

# %%
record_data = pd.DataFrame(record_list)

# proper type to dates
for col in ['creationDate', 'startDate', 'endDate']:
    record_data[col] = pd.to_datetime(record_data[col])

# value is numeric, NaN if fails
record_data['value'] = pd.to_numeric(record_data['value'], errors='coerce')

# some records do not measure anything, just count occurences
# filling with 1.0 (= one time) makes it easier to aggregate
record_data['value'] = record_data['value'].fillna(1.0)

# shorter observation names
record_data['type'] = record_data['type'].str.replace('HKQuantityTypeIdentifier', '')
record_data['type'] = record_data['type'].str.replace('HKCategoryTypeIdentifier', '')
record_data.tail()
# Out:
#                              type           sourceName sourceVersion unit  \
# 1848429  HeartRateVariabilitySDNN  Laine’s Apple Watch          11.6   ms
# 1848430  HeartRateVariabilitySDNN  Laine’s Apple Watch          11.6   ms
# 1848431  HeartRateVariabilitySDNN  Laine’s Apple Watch          11.6   ms
# 1848432  HeartRateVariabilitySDNN  Laine’s Apple Watch          11.6   ms
# 1848433  HeartRateVariabilitySDNN  Laine’s Apple Watch          11.6   ms
#
#                      creationDate                 startDate  \
# 1848429 2025-10-26 19:43:25+02:00 2025-10-26 19:42:24+02:00
# 1848430 2025-10-26 21:19:27+02:00 2025-10-26 21:18:27+02:00
# 1848431 2025-10-27 07:31:33+02:00 2025-10-27 07:30:32+02:00
# 1848432 2025-10-27 10:00:32+02:00 2025-10-27 09:59:32+02:00
# 1848433 2025-10-27 11:19:28+02:00 2025-10-27 11:18:27+02:00
#
#                           endDate    value  \
# 1848429 2025-10-26 19:43:23+02:00  66.0651
# 1848430 2025-10-26 21:19:26+02:00  48.4193
# 1848431 2025-10-27 07:31:31+02:00  36.7700
# 1848432 2025-10-27 10:00:31+02:00  17.6583
# 1848433 2025-10-27 11:19:12+02:00  31.8419
#
#                                                     device
# 1848429  <<HKDevice: 0xd14618be0>, name:Apple Watch, ma...
# 1848430  <<HKDevice: 0xd14618be0>, name:Apple Watch, ma...
# 1848431  <<HKDevice: 0xd14618be0>, name:Apple Watch, ma...
# 1848432  <<HKDevice: 0xd14618be0>, name:Apple Watch, ma...
# 1848433  <<HKDevice: 0xd14618be0>, name:Apple Watch, ma...

# %%
#Unique types of records
record_data['type'].unique()
# Out:
# array(['Height', 'BodyMass', 'HeartRate', 'OxygenSaturation',
#        'BloodPressureSystolic', 'BloodPressureDiastolic',
#        'RespiratoryRate', 'StepCount', 'DistanceWalkingRunning',
#        'BasalEnergyBurned', 'ActiveEnergyBurned', 'FlightsClimbed',
#        'AppleExerciseTime', 'DistanceCycling', 'RestingHeartRate',
#        'VO2Max', 'WalkingHeartRateAverage', 'EnvironmentalAudioExposure',
#        'HeadphoneAudioExposure', 'WalkingDoubleSupportPercentage',
#        'SixMinuteWalkTestDistance', 'AppleStandTime', 'WalkingSpeed',
#        'WalkingStepLength', 'WalkingAsymmetryPercentage',
#        'StairAscentSpeed', 'StairDescentSpeed',
#        'HKDataTypeSleepDurationGoal', 'AppleWalkingSteadiness',
#        'RunningStrideLength', 'RunningVerticalOscillation',
#        'RunningGroundContactTime', 'HeartRateRecoveryOneMinute',
#        'RunningPower', 'RunningSpeed', 'TimeInDaylight', 'PhysicalEffort',
#        'SleepAnalysis', 'AppleStandHour', 'AudioExposureEvent',
#        'HeadphoneAudioExposureEvent', 'LowCardioFitnessEvent',
#        'HeartRateVariabilitySDNN'], dtype=object)

# %%
record_data[record_data['type'] == 'SleepAnalysis'].head(n=100)
# Out:
#                   type      sourceName sourceVersion unit  \
# 1822382  SleepAnalysis  Laine’s iPhone          14.3  NaN
# 1822383  SleepAnalysis  Laine’s iPhone          14.3  NaN
# 1822384  SleepAnalysis  Laine’s iPhone          14.3  NaN
# 1822385  SleepAnalysis  Laine’s iPhone          14.3  NaN
# 1822386  SleepAnalysis  Laine’s iPhone          14.3  NaN
# ...                ...             ...           ...  ...
# 1822477  SleepAnalysis  Laine’s iPhone          14.6  NaN
# 1822478  SleepAnalysis  Laine’s iPhone          14.6  NaN
# 1822479  SleepAnalysis  Laine’s iPhone          14.6  NaN
# 1822480  SleepAnalysis  Laine’s iPhone          14.6  NaN
# 1822481  SleepAnalysis  Laine’s iPhone          14.6  NaN
#
#                      creationDate                 startDate  \
# 1822382 2021-01-10 06:30:09+02:00 2021-01-10 00:27:40+02:00
# 1822383 2021-01-10 06:30:09+02:00 2021-01-10 04:18:30+02:00
# 1822384 2021-01-10 06:30:09+02:00 2021-01-10 05:41:06+02:00
# 1822385 2021-01-11 06:30:06+02:00 2021-01-10 23:57:44+02:00
# 1822386 2021-01-12 07:31:29+02:00 2021-01-12 06:48:08+02:00
# ...                           ...                       ...
# 1822477 2021-06-10 05:39:54+02:00 2021-06-10 00:59:51+02:00
# 1822478 2021-06-10 05:39:54+02:00 2021-06-10 01:32:29+02:00
# 1822479 2021-06-10 05:39:54+02:00 2021-06-10 05:30:37+02:00
# 1822480 2021-06-13 05:30:21+02:00 2021-06-12 22:49:50+02:00
# 1822481 2021-06-14 05:30:12+02:00 2021-06-13 22:39:15+02:00
#
#                           endDate  value device          metric  \
# 1822382 2021-01-10 04:18:26+02:00    1.0    NaN  sleep_analysis
# 1822383 2021-01-10 05:38:52+02:00    1.0    NaN  sleep_analysis
# 1822384 2021-01-10 06:30:09+02:00    1.0    NaN  sleep_analysis
# 1822385 2021-01-11 06:30:06+02:00    1.0    NaN  sleep_analysis
# 1822386 2021-01-12 06:58:19+02:00    1.0    NaN  sleep_analysis
# ...                           ...    ...    ...             ...
# 1822477 2021-06-10 01:32:22+02:00    1.0    NaN  sleep_analysis
# 1822478 2021-06-10 05:30:30+02:00    1.0    NaN  sleep_analysis
# 1822479 2021-06-10 05:39:53+02:00    1.0    NaN  sleep_analysis
# 1822480 2021-06-13 05:30:21+02:00    1.0    NaN  sleep_analysis
# 1822481 2021-06-14 05:30:12+02:00    1.0    NaN  sleep_analysis
#
#          value_canonical        date
# 1822382          13846.0  2021-01-10
# 1822383           4822.0  2021-01-10
# 1822384           2943.0  2021-01-10
# 1822385          23542.0  2021-01-10
# 1822386            611.0  2021-01-12
# ...                  ...         ...
# 1822477           1951.0  2021-06-10
# 1822478          14281.0  2021-06-10
# 1822479            556.0  2021-06-10
# 1822480          24031.0  2021-06-12
# 1822481          24657.0  2021-06-13
#
# [100 rows x 12 columns]

# %%
workout_list = [x.attrib for x in root.iter('Workout')]

# create DataFrame
workout_data = pd.DataFrame(workout_list)
workout_data['workoutActivityType'] = workout_data['workoutActivityType'].str.replace('HKWorkoutActivityType', '')
workout_data = workout_data.rename({"workoutActivityType": "Type"}, axis=1)

# proper type to dates
for col in ['creationDate', 'startDate', 'endDate']:
    workout_data[col] = pd.to_datetime(workout_data[col])

# convert string to numeric   
workout_data['duration'] = pd.to_numeric(workout_data['duration'])
workout_data.tail(n=10)
# Out:
#            Type    duration durationUnit           sourceName sourceVersion  \
# 192     Walking   99.818815          min  Laine’s Apple Watch          11.5
# 193     Walking   86.779552          min  Laine’s Apple Watch          11.5
# 194     Walking   25.732054          min  Laine’s Apple Watch          11.5
# 195     Walking   63.465625          min  Laine’s Apple Watch          11.5
# 196     Walking  394.521379          min  Laine’s Apple Watch          11.5
# 197     Walking   28.430048          min  Laine’s Apple Watch          11.5
# 198  Elliptical   18.396250          min  Laine’s Apple Watch          11.6
# 199     Walking   28.978490          min  Laine’s Apple Watch          11.6
# 200  Elliptical   31.125672          min  Laine’s Apple Watch          11.6
# 201     Walking   34.781556          min  Laine’s Apple Watch          11.6
#
#                                                 device  \
# 192  <<HKDevice: 0xd146054a0>, name:Apple Watch, ma...
# 193  <<HKDevice: 0xd146054a0>, name:Apple Watch, ma...
# 194  <<HKDevice: 0xd146054a0>, name:Apple Watch, ma...
# 195  <<HKDevice: 0xd146054a0>, name:Apple Watch, ma...
# 196  <<HKDevice: 0xd146054a0>, name:Apple Watch, ma...
# 197  <<HKDevice: 0xd146054a0>, name:Apple Watch, ma...
# 198  <<HKDevice: 0xd14619ea0>, name:Apple Watch, ma...
# 199  <<HKDevice: 0xd14619ea0>, name:Apple Watch, ma...
# 200  <<HKDevice: 0xd1461a170>, name:Apple Watch, ma...
# 201  <<HKDevice: 0xd1461a170>, name:Apple Watch, ma...
#
#                  creationDate                 startDate  \
# 192 2025-09-25 19:15:27+02:00 2025-09-25 17:35:30+02:00
# 193 2025-09-26 19:00:46+02:00 2025-09-26 17:33:54+02:00
# 194 2025-09-26 19:50:53+02:00 2025-09-26 19:25:07+02:00
# 195 2025-09-26 21:39:55+02:00 2025-09-26 20:36:21+02:00
# 196 2025-09-27 16:25:02+02:00 2025-09-27 09:50:07+02:00
# 197 2025-09-28 17:54:29+02:00 2025-09-28 17:25:59+02:00
# 198 2025-10-19 18:00:26+02:00 2025-10-19 17:42:01+02:00
# 199 2025-10-19 19:15:26+02:00 2025-10-19 18:46:26+02:00
# 200 2025-10-22 16:12:38+02:00 2025-10-22 15:41:28+02:00
# 201 2025-10-26 15:14:52+02:00 2025-10-26 14:40:02+02:00
#
#                       endDate
# 192 2025-09-25 19:15:19+02:00
# 193 2025-09-26 19:00:41+02:00
# 194 2025-09-26 19:50:51+02:00
# 195 2025-09-26 21:39:49+02:00
# 196 2025-09-27 16:24:38+02:00
# 197 2025-09-28 17:54:25+02:00
# 198 2025-10-19 18:00:25+02:00
# 199 2025-10-19 19:15:24+02:00
# 200 2025-10-22 16:12:35+02:00
# 201 2025-10-26 15:14:49+02:00

# %%
def get_workouts_from_to(df, start, end):
    start = pd.to_datetime(start, utc=True)
    end = pd.to_datetime(end, utc=True)
    workouts = df[df["creationDate"] >= start]
    workouts = workouts[workouts["creationDate"] <= end]
    return workouts

lower_time = dt.date(2021, 1, 1)
upper_time = dt.date(2022, 1, 1)
workouts = get_workouts_from_to(workout_data, lower_time, upper_time)

# or relative to the current day
today = dt.date.today()
xdaysago = today - dt.timedelta(days=7)
# first_of_month = today - dt.timedelta(days=today.day - 1)
workouts = get_workouts_from_to(workout_data, xdaysago, today)

# %% [markdown]
# # === Step 2: Map Apple types to canonical metric names ===

# %%
# mapping dictionary
type_mapping = {
    'BloodPressureSystolic': 'bp_systolic',
    'BloodPressureDiastolic': 'bp_diastolic',
    'ActiveEnergyBurned': 'active_energy',
    'StepCount': 'steps',
    'HeartRate': 'heart_rate',
    'HeartRateVariabilitySDNN': 'hrv_sdnn',
    'BasalEnergyBurned': 'basal_energy',
    'RestingHeartRate': 'resting_hr',
    'WalkingHeartRateAverage': 'walking_hr',
    'DistanceWalkingRunning': 'distance_walk_run',
    'SleepAnalysis': 'sleep_analysis',
    'AppleExerciseTime': 'physical_effort',   # Apple’s exercise minutes
    'Workout': 'physical_effort',             # optional if present
}

# apply mapping, keep unmapped types as-is for exploration
record_data['metric'] = record_data['type'].map(type_mapping).fillna(record_data['type'])

# %% [markdown]
# # === Step 3: Basic unit normalization (convert to canonical units) ===

# %%
def convert_units(row):
    """Convert Apple Health values to canonical units"""
    metric = row['metric']
    unit = row['unit']
    value = row['value']
    
    # Blood pressure: mmHg (convert from kPa if needed)
    if metric == 'bp_systolic' and unit == 'kPa':
        return value * 7.50062
    if metric == 'bp_diastolic' and unit == 'kPa':
        return value * 7.50062
    
    # Distance: km (convert from m)
    if metric == 'distance_walk_run' and unit == 'm':
        return value / 1000.0
    
    # Energy: kcal (convert from J)
    if metric in ['active_energy', 'basal_energy'] and unit == 'J':
        return value / 4184.0
    
    # Time: minutes (for physical effort)
    if metric == 'physical_effort' and unit == 's':
        return value / 60.0
    
    # Sleep: use duration in seconds from start-end
    if metric == 'sleep_analysis':
        duration = (row['endDate'] - row['startDate']).total_seconds()
        return duration
    
    # default: keep raw value
    return value

record_data['value_canonical'] = record_data.apply(convert_units, axis=1)
record_data.tail()
# Out:
#                              type           sourceName sourceVersion unit  \
# 1848429  HeartRateVariabilitySDNN  Laine’s Apple Watch          11.6   ms
# 1848430  HeartRateVariabilitySDNN  Laine’s Apple Watch          11.6   ms
# 1848431  HeartRateVariabilitySDNN  Laine’s Apple Watch          11.6   ms
# 1848432  HeartRateVariabilitySDNN  Laine’s Apple Watch          11.6   ms
# 1848433  HeartRateVariabilitySDNN  Laine’s Apple Watch          11.6   ms
#
#                      creationDate                 startDate  \
# 1848429 2025-10-26 19:43:25+02:00 2025-10-26 19:42:24+02:00
# 1848430 2025-10-26 21:19:27+02:00 2025-10-26 21:18:27+02:00
# 1848431 2025-10-27 07:31:33+02:00 2025-10-27 07:30:32+02:00
# 1848432 2025-10-27 10:00:32+02:00 2025-10-27 09:59:32+02:00
# 1848433 2025-10-27 11:19:28+02:00 2025-10-27 11:18:27+02:00
#
#                           endDate    value  \
# 1848429 2025-10-26 19:43:23+02:00  66.0651
# 1848430 2025-10-26 21:19:26+02:00  48.4193
# 1848431 2025-10-27 07:31:31+02:00  36.7700
# 1848432 2025-10-27 10:00:31+02:00  17.6583
# 1848433 2025-10-27 11:19:12+02:00  31.8419
#
#                                                     device    metric  \
# 1848429  <<HKDevice: 0xd14618be0>, name:Apple Watch, ma...  hrv_sdnn
# 1848430  <<HKDevice: 0xd14618be0>, name:Apple Watch, ma...  hrv_sdnn
# 1848431  <<HKDevice: 0xd14618be0>, name:Apple Watch, ma...  hrv_sdnn
# 1848432  <<HKDevice: 0xd14618be0>, name:Apple Watch, ma...  hrv_sdnn
# 1848433  <<HKDevice: 0xd14618be0>, name:Apple Watch, ma...  hrv_sdnn
#
#          value_canonical        date
# 1848429          66.0651  2025-10-26
# 1848430          48.4193  2025-10-26
# 1848431          36.7700  2025-10-27
# 1848432          17.6583  2025-10-27
# 1848433          31.8419  2025-10-27

# %% [markdown]
# # === Step 4: Derive date field (local calendar day) ===

# %%
record_data['date'] = record_data['startDate'].dt.date

# %%
len(record_data)
# Out:
# 1848434

# %% [markdown]
# ## Filter only this year

# %%
# Get the current year
current_year = dt.date.today().year

# Filter rows where startDate is in the current year
record_data = record_data[record_data['startDate'].dt.year == current_year]

# %%
filtered_counts = record_data[record_data['value_canonical'].notna() & (record_data['value_canonical'] != 0)] \
    .groupby('type')['value_canonical'].count()

# Display the result
print(filtered_counts)
# Out:
# type
# ActiveEnergyBurned                150949
# AppleExerciseTime                  13280
# AppleStandHour                      5056
# AppleStandTime                     19866
# AppleWalkingSteadiness                41
# AudioExposureEvent                   199
# BasalEnergyBurned                 131053
# DistanceCycling                     2703
# DistanceWalkingRunning             87837
# EnvironmentalAudioExposure          5885
# FlightsClimbed                      2829
# HeadphoneAudioExposure              3156
# HeadphoneAudioExposureEvent           19
# HeartRate                         131423
# HeartRateRecoveryOneMinute            56
# HeartRateVariabilitySDNN            1792
# PhysicalEffort                    164000
# RespiratoryRate                     2297
# RestingHeartRate                     291
# RunningGroundContactTime             372
# RunningPower                        1039
# RunningSpeed                        1051
# RunningStrideLength                  371
# RunningVerticalOscillation           379
# SixMinuteWalkTestDistance             41
# SleepAnalysis                       2947
# StairAscentSpeed                    1809
# StairDescentSpeed                   1723
# StepCount                          54592
# TimeInDaylight                      5531
# VO2Max                                99
# WalkingAsymmetryPercentage          1357
# WalkingDoubleSupportPercentage      9060
# WalkingHeartRateAverage              272
# WalkingSpeed                        9961
# WalkingStepLength                   9960
# Name: value_canonical, dtype: int64

# %%
# Group by 'type' and calculate the mean of 'value_canonical'
average_values = record_data.groupby('type')['value_canonical'].mean()

# Filter out rows where the average is not equal to 1
filtered_values = average_values[average_values != 1]

# Display the result
print(filtered_values)
# Out:
# type
# ActiveEnergyBurned                   1.084699
# AppleStandTime                       2.316168
# AppleWalkingSteadiness               0.973277
# BasalEnergyBurned                    3.851476
# DistanceCycling                      0.008049
# DistanceWalkingRunning               0.039020
# EnvironmentalAudioExposure          68.984757
# FlightsClimbed                       1.467656
# HeadphoneAudioExposure              72.267286
# HeartRate                           97.892723
# HeartRateRecoveryOneMinute          28.932641
# HeartRateVariabilitySDNN            45.156980
# PhysicalEffort                       3.718269
# RespiratoryRate                     16.338920
# RestingHeartRate                    61.171821
# RunningGroundContactTime           272.231183
# RunningPower                       178.296439
# RunningSpeed                         8.352166
# RunningStrideLength                  0.914043
# RunningVerticalOscillation           8.860950
# SixMinuteWalkTestDistance          499.487805
# SleepAnalysis                     2320.829997
# StairAscentSpeed                     0.300605
# StairDescentSpeed                    0.343903
# StepCount                           85.507327
# TimeInDaylight                       4.253480
# VO2Max                              29.465556
# WalkingAsymmetryPercentage           0.030794
# WalkingDoubleSupportPercentage       0.282243
# WalkingHeartRateAverage            106.174632
# WalkingSpeed                         4.373109
# WalkingStepLength                   66.641767
# Name: value_canonical, dtype: float64

# %% [markdown]
# ## === Step 5: Aggregate to daily level for the focus metrics ===

# %%
focus_metrics = ['heart_rate', 'physical_effort', 'sleep_analysis', 'basal_energy']

daily_summary = []

for day, group in record_data.groupby('date'):
    row = {'date': day}
    
    # --- Heart Rate (bpm) ---
    hr = group[group['metric'] == 'heart_rate']
    if not hr.empty:
        row['hr_mean'] = hr['value_canonical'].mean()
        row['hr_max'] = hr['value_canonical'].max()
        row['hr_min'] = hr['value_canonical'].min()
        row['hr_count'] = hr.shape[0]
    else:
        row['hr_mean'] = row['hr_max'] = row['hr_min'] = None
        row['hr_count'] = 0
    
    # --- Physical Effort (minutes or counts) ---
    pe = group[group['metric'] == 'physical_effort']
    if not pe.empty:
        row['effort_total'] = pe['value_canonical'].sum()
        row['effort_count'] = pe.shape[0]
        row['had_workout'] = True
    else:
        row['effort_total'] = 0
        row['effort_count'] = 0
        row['had_workout'] = False
    
    # --- Sleep Analysis (seconds → hours) ---
    sl = group[group['metric'] == 'sleep_analysis']
    if not sl.empty:
        total_sleep = sl['value_canonical'].sum()
        row['sleep_seconds'] = total_sleep
        row['sleep_hours'] = total_sleep / 3600.0
        row['sleep_periods'] = sl.shape[0]
    else:
        row['sleep_seconds'] = 0
        row['sleep_hours'] = 0
        row['sleep_periods'] = 0
    
    # --- Basal Energy (kcal) ---
    be = group[group['metric'] == 'basal_energy']
    if not be.empty:
        row['basal_energy_total'] = be['value_canonical'].sum()
        row['basal_energy_mean'] = be['value_canonical'].mean()
        row['basal_energy_count'] = be.shape[0]
    else:
        row['basal_energy_total'] = 0
        row['basal_energy_mean'] = 0
        row['basal_energy_count'] = 0
    
    # append row to list
    daily_summary.append(row)

# convert to DataFrame
daily_summary = (
    pd.DataFrame(daily_summary)
    .sort_values('date')
    .reset_index(drop=True)
)
# Out:
#            date     hr_mean  hr_max   hr_min  hr_count  effort_total  \
# 290  2025-10-18  122.571545   180.0  52.0000       320          40.0
# 291  2025-10-19  107.338821   159.0  57.0000       898          70.0
# 292  2025-10-20   77.287461   145.0  53.0000       206          19.0
# 293  2025-10-21   76.531818   128.0  56.0000       207          18.0
# 294  2025-10-22  107.705338   156.0  50.0000       629          49.0
# 295  2025-10-23   85.843489   169.0  55.6577       294          27.0
# 296  2025-10-24   90.334542   147.0  53.0000       291          14.0
# 297  2025-10-25  100.653465   134.0  57.0000       499          27.0
# 298  2025-10-26  119.226684   150.0  46.0000       673          51.0
# 299  2025-10-27   65.224392   119.0  53.0000        92           3.0
#
#      effort_count  had_workout  sleep_seconds  sleep_hours  ...  \
# 290            40         True            0.0          0.0  ...
# 291            70         True            0.0          0.0  ...
# 292            19         True            0.0          0.0  ...
# 293            18         True            0.0          0.0  ...
# 294            49         True            0.0          0.0  ...
# 295            27         True            0.0          0.0  ...
# 296            14         True            0.0          0.0  ...
# 297            27         True            0.0          0.0  ...
# 298            51         True            0.0          0.0  ...
# 299             3         True            0.0          0.0  ...
#
#      basal_energy_mean  basal_energy_count  hr_mean_delta  hr_mean_pct_change  \
# 290           4.334047                 386      36.223874           41.951189
# 291           1.970071                 887     -15.232724          -12.427619
# 292          12.874861                 137     -30.051360          -27.996730
# 293          17.974292                  96      -0.755643           -0.977704
# 294           1.893871                 804      31.173520           40.732758
# 295           7.559233                 189     -21.861849          -20.297833
# 296          12.312706                 136       4.491053            5.231676
# 297           8.814281                 192      10.318923           11.423009
# 298           2.180953                 800      18.573219           18.452637
# 299          15.991962                  53     -54.002291          -45.293796
#
#      effort_total_delta  effort_total_pct_change  sleep_hours_delta  \
# 290                18.0                81.818182                0.0
# 291                30.0                75.000000                0.0
# 292               -51.0               -72.857143                0.0
# 293                -1.0                -5.263158                0.0
# 294                31.0               172.222222                0.0
# 295               -22.0               -44.897959                0.0
# 296               -13.0               -48.148148                0.0
# 297                13.0                92.857143                0.0
# 298                24.0                88.888889                0.0
# 299               -48.0               -94.117647                0.0
#
#      sleep_hours_pct_change  basal_energy_total_delta  \
# 290                     NaN                   -86.384
# 291                     NaN                    74.511
# 292                     NaN                    16.403
# 293                     NaN                   -38.324
# 294                     NaN                  -202.860
# 295                     NaN                   -93.977
# 296                     NaN                   245.833
# 297                     NaN                    17.814
# 298                     NaN                    52.420
# 299                     NaN                  -897.188
#
#      basal_energy_total_pct_change
# 290                      -4.910062
# 291                       4.453890
# 292                       0.938680
# 293                      -2.172740
# 294                     -11.756374
# 295                      -6.171848
# 296                      17.206822
# 297                       1.063822
# 298                       3.097483
# 299                     -51.421799
#
# [10 rows x 22 columns]
# /var/folders/fh/dds9257s5y927c0kq_nq0fhr0000gn/T/ipykernel_16639/1691144719.py:66: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_summary[f'{col}_pct_change'] = daily_summary[col].pct_change() * 100

# %%
# preview
print(daily_summary.head(10))
# Out:
#          date    hr_mean  hr_max  hr_min  hr_count  effort_total  \
# 0  2025-01-01  94.754027   145.0    53.0       152           9.0
# 1  2025-01-02  67.925285   119.0    48.0       199          15.0
# 2  2025-01-03  68.088741   130.0    53.0       187          25.0
# 3  2025-01-04  81.559653   166.0    49.0       335          40.0
# 4  2025-01-05  72.939575   105.0    61.0       110           3.0
# 5  2025-01-06  82.321848   130.0    57.0       264          23.0
# 6  2025-01-07  81.948835   137.0    59.0       249          21.0
# 7  2025-01-08  82.391835   115.0    56.0       174          21.0
# 8  2025-01-09  83.281527   124.0    63.0       220          15.0
# 9  2025-01-10  87.844940   150.0    56.0       242          24.0
#
#    effort_count  had_workout  sleep_seconds  sleep_hours  ...  \
# 0             9         True        60010.0    16.669444  ...
# 1            15         True        13074.0     3.631667  ...
# 2            25         True            0.0     0.000000  ...
# 3            40         True         5632.0     1.564444  ...
# 4             3         True        58927.0    16.368611  ...
# 5            23         True        37903.0    10.528611  ...
# 6            21         True        36883.0    10.245278  ...
# 7            21         True        41161.0    11.433611  ...
# 8            15         True        13142.0     3.650556  ...
# 9            24         True            0.0     0.000000  ...
#
#    basal_energy_mean  basal_energy_count  hr_mean_delta  hr_mean_pct_change  \
# 0          13.624372                 129            NaN                 NaN
# 1          20.204023                  88     -26.828742          -28.314091
# 2          16.188779                 104       0.163455            0.240640
# 3          12.064357                 143      13.470912           19.784347
# 4          29.420519                  52      -8.620078          -10.569047
# 5          10.759339                 165       9.382273           12.863075
# 6          10.488750                 124      -0.373013           -0.453115
# 7           8.991689                 196       0.443000            0.540581
# 8          14.752790                 119       0.889692            1.079831
# 9          13.830887                 124       4.563413            5.479502
#
#    effort_total_delta  effort_total_pct_change  sleep_hours_delta  \
# 0                 NaN                      NaN                NaN
# 1                 6.0                66.666667         -13.037778
# 2                10.0                66.666667          -3.631667
# 3                15.0                60.000000           1.564444
# 4               -37.0               -92.500000          14.804167
# 5                20.0               666.666667          -5.840000
# 6                -2.0                -8.695652          -0.283333
# 7                 0.0                 0.000000           1.188333
# 8                -6.0               -28.571429          -7.783056
# 9                 9.0                60.000000          -3.650556
#
#    sleep_hours_pct_change  basal_energy_total_delta  \
# 0                     NaN                       NaN
# 1              -78.213631                    20.410
# 2             -100.000000                   -94.321
# 3                     inf                    41.570
# 4              946.289062                  -195.336
# 5              -35.678042                   245.424
# 6               -2.691080                  -474.686
# 7               11.598840                   461.766
# 8              -68.071718                    -6.789
# 9             -100.000000                   -40.552
#
#    basal_energy_total_pct_change
# 0                            NaN
# 1                       1.161280
# 2                      -5.305030
# 3                       2.469065
# 4                     -11.322494
# 5                      16.042179
# 6                     -26.738490
# 7                      35.503939
# 8                      -0.385220
# 9                      -2.309889
#
# [10 rows x 22 columns]

# %% [markdown]
# ## === Step 6: Compute day-to-day changes ===

# %%
# === Step: Compute day-to-day deltas (for main metrics) ===
for col in ['hr_mean', 'effort_total', 'sleep_hours', 'basal_energy_total']:
    daily_summary[f'{col}_delta'] = daily_summary[col].diff()
    daily_summary[f'{col}_pct_change'] = daily_summary[col].pct_change() * 100
# Out:
# /var/folders/fh/dds9257s5y927c0kq_nq0fhr0000gn/T/ipykernel_16639/203796006.py:4: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_summary[f'{col}_pct_change'] = daily_summary[col].pct_change() * 100

# %%
print(daily_summary.head(100))
# Out:
#           date    hr_mean   hr_max  hr_min  hr_count  effort_total  \
# 0   2025-01-01  94.754027  145.000    53.0       152           9.0
# 1   2025-01-02  67.925285  119.000    48.0       199          15.0
# 2   2025-01-03  68.088741  130.000    53.0       187          25.0
# 3   2025-01-04  81.559653  166.000    49.0       335          40.0
# 4   2025-01-05  72.939575  105.000    61.0       110           3.0
# ..         ...        ...      ...     ...       ...           ...
# 95  2025-04-06  92.519176  164.295    50.0       262          56.0
# 96  2025-04-07  80.428611  167.128    47.0       254          41.0
# 97  2025-04-08  86.505096  151.000    54.0       370          47.0
# 98  2025-04-09  81.460324  137.000    56.0       265          41.0
# 99  2025-04-10  80.375612  173.000    55.0       244          34.0
#
#     effort_count  had_workout  sleep_seconds  sleep_hours  ...  \
# 0              9         True        60010.0    16.669444  ...
# 1             15         True        13074.0     3.631667  ...
# 2             25         True            0.0     0.000000  ...
# 3             40         True         5632.0     1.564444  ...
# 4              3         True        58927.0    16.368611  ...
# ..           ...          ...            ...          ...  ...
# 95            56         True        60311.0    16.753056  ...
# 96            41         True        32369.0     8.991389  ...
# 97            47         True        36884.0    10.245556  ...
# 98            41         True        34481.0     9.578056  ...
# 99            34         True        11708.0     3.252222  ...
#
#     basal_energy_mean  basal_energy_count  hr_mean_delta  hr_mean_pct_change  \
# 0           13.624372                 129            NaN                 NaN
# 1           20.204023                  88     -26.828742          -28.314091
# 2           16.188779                 104       0.163455            0.240640
# 3           12.064357                 143      13.470912           19.784347
# 4           29.420519                  52      -8.620078          -10.569047
# ..                ...                 ...            ...                 ...
# 95           7.857631                 222     -29.338428          -24.075993
# 96          15.915358                 106     -12.090565          -13.068172
# 97           8.690459                 159       6.076485            7.555129
# 98          10.911455                 167      -5.044772           -5.831763
# 99          10.219556                 178      -1.084712           -1.331584
#
#     effort_total_delta  effort_total_pct_change  sleep_hours_delta  \
# 0                  NaN                      NaN                NaN
# 1                  6.0                66.666667         -13.037778
# 2                 10.0                66.666667          -3.631667
# 3                 15.0                60.000000           1.564444
# 4                -37.0               -92.500000          14.804167
# ..                 ...                      ...                ...
# 95               -47.0               -45.631068          14.420833
# 96               -15.0               -26.785714          -7.761667
# 97                 6.0                14.634146           1.254167
# 98                -6.0               -12.765957          -0.667500
# 99                -7.0               -17.073171          -6.325833
#
#     sleep_hours_pct_change  basal_energy_total_delta  \
# 0                      NaN                       NaN
# 1               -78.213631                    20.410
# 2              -100.000000                   -94.321
# 3                      inf                    41.570
# 4               946.289062                  -195.336
# ..                     ...                       ...
# 95              618.330157                   -32.342
# 96              -46.329857                   -57.366
# 97               13.948531                  -305.245
# 98               -6.515020                   440.430
# 99              -66.045068                    -3.132
#
#     basal_energy_total_pct_change
# 0                             NaN
# 1                        1.161280
# 2                       -5.305030
# 3                        2.469065
# 4                      -11.322494
# ..                            ...
# 95                      -1.820304
# 96                      -3.288592
# 97                     -18.093653
# 98                      31.874035
# 99                      -0.171879
#
# [100 rows x 22 columns]

# %% [markdown]
# ## == Adding z-score

# %%
# window size for baseline (number of previous days)
BASELINE_WINDOW = 7   # you can set to 14 if you prefer

metrics_for_z = ['hr_mean', 'effort_total', 'sleep_hours', 'basal_energy_total']

# sort by date just in case
daily_summary = daily_summary.sort_values('date').reset_index(drop=True)

for col in metrics_for_z:
    # compute rolling mean and std using only previous N days (exclude current)
    daily_summary[f'{col}_baseline_mean'] = (
        daily_summary[col]
        .shift(1)  # exclude today
        .rolling(window=BASELINE_WINDOW, min_periods=3)  # need at least 3 days to start
        .mean()
    )
    daily_summary[f'{col}_baseline_std'] = (
        daily_summary[col]
        .shift(1)
        .rolling(window=BASELINE_WINDOW, min_periods=3)
        .std()
    )
    
    # compute z-score relative to baseline
    # z = (today_value - baseline_mean) / baseline_std
    daily_summary[f'{col}_zscore'] = (
        (daily_summary[col] - daily_summary[f'{col}_baseline_mean']) /
        daily_summary[f'{col}_baseline_std']
    )

# Optionally: replace very large or NaN z-scores for stability
for col in metrics_for_z:
    z_col = f'{col}_zscore'
    daily_summary[z_col] = daily_summary[z_col].replace([np.inf, -np.inf], np.nan)
    # clip to [-5, 5] if you want to limit extreme outliers
    daily_summary[z_col] = daily_summary[z_col].clip(-5, 5)

# %%
print(daily_summary[['date'] + [f'{m}_zscore' for m in metrics_for_z]].tail(100))
# Out:
#            date  hr_mean_zscore  effort_total_zscore  sleep_hours_zscore  \
# 200  2025-07-20        0.318702             2.060714            0.985176
# 201  2025-07-21        3.997612            -0.053812            0.448056
# 202  2025-07-22       -0.005402             0.216348           -1.076612
# 203  2025-07-23       -1.698156            -0.567912           -1.210694
# 204  2025-07-24       -0.497965            -0.321545           -0.909374
# ..          ...             ...                  ...                 ...
# 295  2025-10-23       -0.637202            -0.466936                 NaN
# 296  2025-10-24       -0.252004            -1.090756                 NaN
# 297  2025-10-25        0.302070            -0.336817                 NaN
# 298  2025-10-26        2.037117             0.936063                 NaN
# 299  2025-10-27       -1.796578            -1.760598                 NaN
#
#      basal_energy_total_zscore
# 200                   0.953002
# 201                  -0.100161
# 202                   0.391846
# 203                   0.136933
# 204                   1.134859
# ..                         ...
# 295                  -3.167731
# 296                   0.109244
# 297                   0.353781
# 298                   0.744416
# 299                  -5.000000
#
# [100 rows x 5 columns]

# %% [markdown]
# ### Rule engine: mapping signals → suggestions

# %%
rules_df = pd.read_csv('RuleBank_v3.csv')

# %%
rules_df['symptom']
# Out:
# 0                     sleep
# 1                     sleep
# 2                     sleep
# 3                    stress
# 4                    energy
# 5                 vasomotor
# 6                     sleep
# 7                     sleep
# 8                    stress
# 9                    energy
# 10              environment
# 11              food_timing
# 12                hydration
# 13    journaling/behavioral
# 14                   safety
# 15                   energy
# Name: symptom, dtype: object

# %%
import re

# %%
def parse_condition(expr):
    """
    Example: '[sleep_efficiency@last_night < baseline − 1.0SD]'
    returns {'metric': 'sleep_efficiency', 'operator': '<', 'threshold': -1.0, 'window': 'last_night'}
    """
    pattern = r'\[(\w+)@(\w+)\s*([<>]=?|==)\s*baseline\s*[\-+]\s*([0-9.]+)SD\]'
    m = re.search(pattern, expr.replace('−', '-'))  # normalize minus symbol
    if m:
        metric, window, op, sd = m.groups()
        sign = -1 if '-' in expr else 1
        return {'metric': metric, 'window': window, 'operator': op, 'sd_offset': sign * float(sd)}
    return None

rules_df['parsed_conditions'] = rules_df['IF'].apply(parse_condition)

# %%
def parse_if_clause(expr: str):
    """
    Parse clauses like:
    '[sleep_efficiency@last_night < baseline − 1.0SD] AND [data_confidence ≥ 70]'
    into structured dict(s).
    """
    expr = str(expr).replace('−', '-')  # normalize minus sign
    
    metric_pattern = r'(\w+)@(\w+)\s*([<>]=?|==)\s*baseline\s*([+-])\s*([\d.]+)SD'
    conf_pattern = r'data_confidence\s*([<>]=?|==)\s*(\d+)'
    
    metric_match = re.search(metric_pattern, expr)
    conf_match = re.search(conf_pattern, expr)
    
    parsed = {}
    if metric_match:
        metric, window, op, sign, sd = metric_match.groups()
        parsed.update({
            'metric': metric,
            'window': window,
            'operator': op,
            'sd_offset': float(sd) * (-1 if sign == '-' else 1)
        })
    if conf_match:
        conf_op, conf_val = conf_match.groups()
        parsed.update({
            'data_confidence_operator': conf_op,
            'data_confidence_threshold': float(conf_val)
        })
    
    return parsed or None

rules_df['parsed'] = rules_df['IF'].apply(parse_if_clause)

# %%
rules_df.head()
# Out:
#   rule_id symptom                                                 IF  \
# 0    R601   sleep  [sleep_efficiency@last_night < baseline − 1.0S...
# 1    R602   sleep  [sleep_latency@last_night > baseline + 1.0SD] ...
# 2    R603   sleep  [sleep_awakenings@last_night > baseline + 1.0S...
# 3    R604  stress  [hrv (night)@last_night < baseline − 1.0SD AND...
# 4    R605  energy  [resting_hr (day)@last_24h > baseline + 1.0SD ...
#
#    data_confidence_threshold  \
# 0                         70
# 1                         70
# 2                         70
# 3                         70
# 4                         70
#
#                                               UNLESS  \
# 0  Alcohol last 24h; Illness or fever present; Me...
# 1  Late caffeine; Late heavy meal; Night/rotating...
# 2  Very hot night; Severe night sweats logged; Al...
# 3  Acute stress event; Illness or fever present; ...
# 4  Illness or fever present; Intense exercise day...
#
#                                              THEN  \
# 0           Keep the same wake-up time every day.
# 1                     Avoid caffeine after lunch.
# 2  Wear breathable layers you can remove quickly.
# 3       Do 10 minutes of mindful breathing today.
# 4        Take a brisk 10-minute walk mid-morning.
#
#                                              BECAUSE REFER  \
# 0  Regular timing stabilizes sleep pressure and r...    No
# 1              Later caffeine can delay sleep onset.    No
# 2              Cooling options reduce warm wake-ups.    No
# 3         Brief relaxation can help on low-HRV days.    No
# 4        Light movement safely lifts daytime energy.    No
#
#                                               SOURCE  \
# 0  ALSWH submission, 2024; Lancet empowerment mod...
# 1                     Lancet empowerment model, 2024
# 2                             ALSWH submission, 2024
# 3                  Lancet mental health review, 2024
# 4                             ALSWH submission, 2024
#
#                                                NOTES evidence_tier  \
# 0  Data confidence = min(sensor_quality_score_wei...             B
# 1  Sleep signals ignore GPX; sensor_quality falls...             B
# 2  If temp missing, lower priority; GPX affects o...             B
# 3  Require night window ≥80%; HRV σ_floor=5 ms; G...             B
# 4  activity_intensity from ActivityIntensity_ByDa...             B
#
#    windows_baseline_days  windows_trend_days windows_event  cooldown_days  \
# 0                     30                   3    last_night              2
# 1                     30                   3    last_night              2
# 2                     30                   3    last_night              2
# 3                     30                   3    last_night              1
# 4                     30                   3      last_24h              1
#
#    priority                                         unit_tests  \
# 0        90  Fires: efficiency −1.2SD, confidence 82. || Su...
# 1        90  Fires: latency +1.1SD, confidence 78. || Suppr...
# 2        90  Fires: awakenings +1.0SD & temp +0.6SD. || Sup...
# 3        80  Fires: HRV −1.2SD & stress tag. || Suppressed:...
# 4        70  Fires: RHR +1.2SD & activity_intensity low. ||...
#
#                                               parsed  \
# 0  {'metric': 'sleep_efficiency', 'window': 'last...
# 1  {'metric': 'sleep_latency', 'window': 'last_ni...
# 2  {'metric': 'sleep_awakenings', 'window': 'last...
# 3                                               None
# 4  {'metric': 'activity_intensity', 'window': 'la...
#
#                                    parsed_conditions
# 0  {'metric': 'sleep_efficiency', 'window': 'last...
# 1  {'metric': 'sleep_latency', 'window': 'last_ni...
# 2                                               None
# 3                                               None
# 4                                               None

# %%
def to_json_row(row):
    return {
        'rule_id': row['rule_id'],
        'symptom': row['symptom'],
        'condition': row['parsed'],
        'unless': [u.strip() for u in str(row['UNLESS']).split(';') if u.strip() and u.strip() != '—'],
        'then': row['THEN'],
        'because': row['BECAUSE'],
        'reference': row.get('REFER'),
        'source': row.get('SOURCE'),
        'evidence_tier': row.get('evidence_tier'),
        'window_params': {
            'baseline_days': row.get('windows_baseline_days'),
            'trend_days': row.get('windows_trend_days'),
            'event': row.get('windows_event'),
            'cooldown_days': row.get('cooldown_days'),
        },
        'priority': row.get('priority'),
    }

rules_json = [to_json_row(rules_df.iloc[i]) for i in range(len(rules_df))]

# %%
rules_json
# Out:
# [{'rule_id': 'R601',
#   'symptom': 'sleep',
#   'condition': {'metric': 'sleep_efficiency',
#    'window': 'last_night',
#    'operator': '<',
#    'sd_offset': -1.0},
#   'unless': ['Alcohol last 24h',
#    'Illness or fever present',
#    'Menstruation day 1–2',
#    'Night/rotating shift',
#    'Travel/time-zone shift',
#    'Noisy/bright sleep environment',
#    'Device off-wrist/loose fit'],
#   'then': 'Keep the same wake-up time every day.',
#   'because': 'Regular timing stabilizes sleep pressure and routine.',
#   'reference': 'No',
#   'source': 'ALSWH submission, 2024; Lancet empowerment model, 2024',
#   'evidence_tier': 'B',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_night',
#    'cooldown_days': np.int64(2)},
#   'priority': np.int64(90)},
#  {'rule_id': 'R602',
#   'symptom': 'sleep',
#   'condition': {'metric': 'sleep_latency',
#    'window': 'last_night',
#    'operator': '>',
#    'sd_offset': 1.0},
#   'unless': ['Late caffeine',
#    'Late heavy meal',
#    'Night/rotating shift',
#    'Travel/time-zone shift',
#    'Device off-wrist/loose fit'],
#   'then': 'Avoid caffeine after lunch.',
#   'because': 'Later caffeine can delay sleep onset.',
#   'reference': 'No',
#   'source': 'Lancet empowerment model, 2024',
#   'evidence_tier': 'B',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_night',
#    'cooldown_days': np.int64(2)},
#   'priority': np.int64(90)},
#  {'rule_id': 'R603',
#   'symptom': 'sleep',
#   'condition': {'metric': 'sleep_awakenings',
#    'window': 'last_night',
#    'operator': '>',
#    'sd_offset': 1.0},
#   'unless': ['Very hot night',
#    'Severe night sweats logged',
#    'Alcohol last 24h',
#    'Sauna/hot bath last evening',
#    'Device off-wrist/loose fit'],
#   'then': 'Wear breathable layers you can remove quickly.',
#   'because': 'Cooling options reduce warm wake-ups.',
#   'reference': 'No',
#   'source': 'ALSWH submission, 2024',
#   'evidence_tier': 'B',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_night',
#    'cooldown_days': np.int64(2)},
#   'priority': np.int64(90)},
#  {'rule_id': 'R604',
#   'symptom': 'stress',
#   'condition': None,
#   'unless': ['Acute stress event',
#    'Illness or fever present',
#    'Menstruation day 1–2',
#    'Travel/time-zone shift',
#    'Device off-wrist/loose fit'],
#   'then': 'Do 10 minutes of mindful breathing today.',
#   'because': 'Brief relaxation can help on low-HRV days.',
#   'reference': 'No',
#   'source': 'Lancet mental health review, 2024',
#   'evidence_tier': 'B',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_night',
#    'cooldown_days': np.int64(1)},
#   'priority': np.int64(80)},
#  {'rule_id': 'R605',
#   'symptom': 'energy',
#   'condition': {'metric': 'activity_intensity',
#    'window': 'last_24h',
#    'operator': '<',
#    'sd_offset': -0.5},
#   'unless': ['Illness or fever present',
#    'Intense exercise day',
#    'Low hydration day',
#    'Travel/time-zone shift',
#    'Device off-wrist/loose fit'],
#   'then': 'Take a brisk 10-minute walk mid-morning.',
#   'because': 'Light movement safely lifts daytime energy.',
#   'reference': 'No',
#   'source': 'ALSWH submission, 2024',
#   'evidence_tier': 'B',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_24h',
#    'cooldown_days': np.int64(1)},
#   'priority': np.int64(70)},
#  {'rule_id': 'R606',
#   'symptom': 'vasomotor',
#   'condition': {'metric': 'temp_deviation',
#    'window': 'last_night',
#    'operator': '>',
#    'sd_offset': 0.5},
#   'unless': ['Very hot night',
#    'Severe night sweats logged',
#    'Alcohol last 24h',
#    'Sauna/hot bath last evening',
#    'Device off-wrist/loose fit'],
#   'then': 'Limit alcohol in the evening.',
#   'because': 'Alcohol can worsen warm wake-ups.',
#   'reference': 'No',
#   'source': 'ALSWH submission, 2024',
#   'evidence_tier': 'B',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_night',
#    'cooldown_days': np.int64(2)},
#   'priority': np.int64(60)},
#  {'rule_id': 'R607',
#   'symptom': 'sleep',
#   'condition': {'metric': 'sleep_duration',
#    'window': 'last_night',
#    'operator': '<',
#    'sd_offset': -1.0},
#   'unless': ['Night/rotating shift',
#    'Travel/time-zone shift',
#    'Noisy/bright sleep environment',
#    'Illness or fever present',
#    'Device off-wrist/loose fit'],
#   'then': 'Set your bedroom cooler before bed.',
#   'because': 'Cooler rooms support fewer wake-ups.',
#   'reference': 'No',
#   'source': 'Lancet empowerment model, 2024',
#   'evidence_tier': 'B',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_night',
#    'cooldown_days': np.int64(2)},
#   'priority': np.int64(90)},
#  {'rule_id': 'R608',
#   'symptom': 'sleep',
#   'condition': {'metric': 'sleep_latency',
#    'window': 'last_night',
#    'operator': '>',
#    'sd_offset': 0.5},
#   'unless': ['Night/rotating shift',
#    'Travel/time-zone shift',
#    'Late heavy meal',
#    'Noisy/bright sleep environment',
#    'Device off-wrist/loose fit'],
#   'then': 'Start a 30-minute wind-down without screens.',
#   'because': 'A calm routine helps sleep readiness.',
#   'reference': 'No',
#   'source': 'Lancet empowerment model, 2024',
#   'evidence_tier': 'B',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_night',
#    'cooldown_days': np.int64(2)},
#   'priority': np.int64(90)},
#  {'rule_id': 'R609',
#   'symptom': 'stress',
#   'condition': None,
#   'unless': ['Acute stress event',
#    'Illness or fever present',
#    'Menstruation day 1–2',
#    'Travel/time-zone shift',
#    'Device off-wrist/loose fit'],
#   'then': 'Write one worry and one next step.',
#   'because': 'Externalizing worries can settle the mind.',
#   'reference': 'No',
#   'source': 'Lancet mental health review, 2024',
#   'evidence_tier': 'B',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_night',
#    'cooldown_days': np.int64(1)},
#   'priority': np.int64(80)},
#  {'rule_id': 'R610',
#   'symptom': 'energy',
#   'condition': {'metric': 'activity_intensity',
#    'window': 'last_24h',
#    'operator': '<',
#    'sd_offset': -1.0},
#   'unless': ['Pain flare day',
#    'Intense exercise day',
#    'Illness or fever present',
#    'Low hydration day',
#    'Device off-wrist/loose fit'],
#   'then': 'Stand and stretch for one minute each hour.',
#   'because': 'Frequent light movement boosts focus.',
#   'reference': 'No',
#   'source': 'ALSWH submission, 2024',
#   'evidence_tier': 'B',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_24h',
#    'cooldown_days': np.int64(1)},
#   'priority': np.int64(70)},
#  {'rule_id': 'R611',
#   'symptom': 'environment',
#   'condition': {'metric': 'sleep_awakenings',
#    'window': 'last_night',
#    'operator': '>',
#    'sd_offset': 1.0},
#   'unless': ['Noisy/bright sleep environment',
#    'Very hot night',
#    'Very cold night',
#    'Alcohol last 24h',
#    'Device off-wrist/loose fit'],
#   'then': 'Dim lights one hour before bed.',
#   'because': 'Lower evening light supports sleep readiness.',
#   'reference': 'No',
#   'source': 'ALSWH submission, 2024',
#   'evidence_tier': 'B',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_night',
#    'cooldown_days': np.int64(2)},
#   'priority': np.int64(50)},
#  {'rule_id': 'R612',
#   'symptom': 'food_timing',
#   'condition': {'metric': 'sleep_efficiency',
#    'window': 'last_night',
#    'operator': '<',
#    'sd_offset': -0.5},
#   'unless': ['Late heavy meal',
#    'Late caffeine',
#    'Night/rotating shift',
#    'Travel/time-zone shift',
#    'Device off-wrist/loose fit'],
#   'then': 'Finish your last meal two to three hours before bed.',
#   'because': 'Earlier meals can aid comfort at bedtime.',
#   'reference': 'No',
#   'source': 'ALSWH submission, 2024',
#   'evidence_tier': 'C',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_night',
#    'cooldown_days': np.int64(2)},
#   'priority': np.int64(50)},
#  {'rule_id': 'R613',
#   'symptom': 'hydration',
#   'condition': {'metric': 'activity_intensity',
#    'window': 'last_24h',
#    'operator': '>',
#    'sd_offset': 0.5},
#   'unless': ['Intense exercise day',
#    'Low hydration day',
#    'Illness or fever present',
#    'Travel/time-zone shift',
#    'Device off-wrist/loose fit'],
#   'then': 'Have water with each meal today.',
#   'because': 'Hydration supports heart rate and energy.',
#   'reference': 'No',
#   'source': 'ALSWH submission, 2024',
#   'evidence_tier': 'B',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_24h',
#    'cooldown_days': np.int64(1)},
#   'priority': np.int64(50)},
#  {'rule_id': 'R614',
#   'symptom': 'journaling/behavioral',
#   'condition': None,
#   'unless': [],
#   'then': 'Write a two-line worry list at 18:00.',
#   'because': 'Simple journaling can ease evening tension.',
#   'reference': 'No',
#   'source': 'Lancet mental health review, 2024',
#   'evidence_tier': 'B',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_24h',
#    'cooldown_days': np.int64(1)},
#   'priority': np.int64(80)},
#  {'rule_id': 'R617',
#   'symptom': 'safety',
#   'condition': None,
#   'unless': [],
#   'then': '—',
#   'because': '—',
#   'reference': 'Yes: Your data and notes suggest a safety concern. Please contact a clinician or urgent care today.',
#   'source': 'ALSWH submission, 2024',
#   'evidence_tier': 'A',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_24h',
#    'cooldown_days': np.int64(2)},
#   'priority': np.int64(100)},
#  {'rule_id': 'R-ENERGY-PR-01',
#   'symptom': 'energy',
#   'condition': {'metric': 'activity_intensity',
#    'window': 'last_24h',
#    'operator': '>',
#    'sd_offset': 1.0},
#   'unless': ['device_off_wrist OR low sensor_quality OR illness/fever'],
#   'then': 'Include a protein-rich food in your next meal.',
#   'because': 'Hard training strains muscles; protein helps repair and maintain them.',
#   'reference': 'No',
#   'source': 'Women40+_Experts/Unknown',
#   'evidence_tier': 'C',
#   'window_params': {'baseline_days': np.int64(30),
#    'trend_days': np.int64(3),
#    'event': 'last_24h',
#    'cooldown_days': np.int64(1)},
#   'priority': np.int64(60)}]

# %%
import json

with open("rules_bank.json", "w", encoding="utf-8") as f:
    json.dump(rules_json, f, indent=2, ensure_ascii=False)

print(f"Saved {len(rules_json)} rules to rules_bank.json")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 4
#       1 import json
#       3 with open("rules_bank.json", "w", encoding="utf-8") as f:
# ----> 4     json.dump(rules_json, f, indent=2, ensure_ascii=False)
#       6 print(f"Saved {len(rules_json)} rules to rules_bank.json")
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/encoder.py:430, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     428     yield _floatstr(o)
#     429 elif isinstance(o, (list, tuple)):
# --> 430     yield from _iterencode_list(o, _current_indent_level)
#     431 elif isinstance(o, dict):
#     432     yield from _iterencode_dict(o, _current_indent_level)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/encoder.py:326, in _make_iterencode.<locals>._iterencode_list(lst, _current_indent_level)
#     324         else:
#     325             chunks = _iterencode(value, _current_indent_level)
# --> 326         yield from chunks
#     327 if newline_indent is not None:
#     328     _current_indent_level -= 1
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/encoder.py:406, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     404         else:
#     405             chunks = _iterencode(value, _current_indent_level)
# --> 406         yield from chunks
#     407 if newline_indent is not None:
#     408     _current_indent_level -= 1
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/encoder.py:406, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     404         else:
#     405             chunks = _iterencode(value, _current_indent_level)
# --> 406         yield from chunks
#     407 if newline_indent is not None:
#     408     _current_indent_level -= 1
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/encoder.py:439, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     437         raise ValueError("Circular reference detected")
#     438     markers[markerid] = o
# --> 439 o = _default(o)
#     440 yield from _iterencode(o, _current_indent_level)
#     441 if markers is not None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)    178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type int64 is not JSON serializable

# %% [markdown]
# ### Fire rules

# %%
def evaluate_rule(rule, row):
    """Evaluate a single rule on a given day's data"""
    cond = rule["condition"]
    metric = cond["metric"]
    z_col = f"{metric}_zscore"

    if z_col not in row: 
        return False, None

    z_value = row[z_col]

    # zscore condition
    operator = cond["operator"]
    sd_offset = cond["sd_offset"]
    if operator == ">" and not (z_value > sd_offset):
        return False, None
    if operator == "<" and not (z_value < sd_offset):
        return False, None

    # confidence condition
    # conf_op = cond.get("data_confidence_operator", ">=")
    # conf_thresh = cond.get("data_confidence_threshold", 70)
    # if conf_op == ">=" and conf_value < conf_thresh:
    #     return False, None
    # if conf_op == "<=" and conf_value > conf_thresh:
    #     return False, None

    return True, z_value

# %%
def apply_rules(df, rules):
    """Apply all rules to the entire daily summary DataFrame"""
    results = []
    for date, row in df.iterrows():
        for rule in rules:
            fires, z_value = evaluate_rule(rule, row)
            if fires:
                results.append({
                    "date": row['date'],
                    "rule_id": rule["rule_id"],
                    "symptom": rule["symptom"],
                    "metric": rule["condition"]["metric"],
                    "z_value": round(z_value, 2),
                    "suggestion": rule["then"],
                    "because": rule["because"],
                    "priority": rule["priority"],
                    "source": rule["source"]
                })
    return pd.DataFrame(results)

# %%
with open("rules_bank.json", "r") as f:
    rules = json.load(f)

# %%
daily_summary.columns
# Out:
# Index(['date', 'hr_mean', 'hr_max', 'hr_min', 'hr_count', 'effort_total',
#        'effort_count', 'had_workout', 'sleep_seconds', 'sleep_hours',
#        'sleep_periods', 'basal_energy_total', 'basal_energy_mean',
#        'basal_energy_count', 'hr_mean_delta', 'hr_mean_pct_change',
#        'effort_total_delta', 'effort_total_pct_change', 'sleep_hours_delta',
#        'sleep_hours_pct_change', 'basal_energy_total_delta',
#        'basal_energy_total_pct_change', 'hr_mean_baseline_mean',
#        'hr_mean_baseline_std', 'hr_mean_zscore', 'effort_total_baseline_mean',
#        'effort_total_baseline_std', 'effort_total_zscore',
#        'sleep_hours_baseline_mean', 'sleep_hours_baseline_std',
#        'sleep_hours_zscore', 'basal_energy_total_baseline_mean',
#        'basal_energy_total_baseline_std', 'basal_energy_total_zscore'],
#       dtype='object')

# %%
results = apply_rules(daily_summary, rules)
print(results)
# Out:
#            date rule_id           symptom              metric  z_value  \
# 0    2025-01-05   R1002      low_activity        effort_total    -1.42
# 1    2025-01-10   R1001       cardio_load             hr_mean     1.50
# 2    2025-01-10   R1003     sleep_deficit         sleep_hours    -1.28
# 3    2025-01-11   R1001       cardio_load             hr_mean     5.00
# 4    2025-01-11   R1003     sleep_deficit         sleep_hours    -1.11
# ..          ...     ...               ...                 ...      ...
# 162  2025-10-16   R1004  metabolic_energy  basal_energy_total     1.03
# 163  2025-10-18   R1001       cardio_load             hr_mean     3.33
# 164  2025-10-24   R1002      low_activity        effort_total    -1.09
# 165  2025-10-26   R1001       cardio_load             hr_mean     2.04
# 166  2025-10-27   R1002      low_activity        effort_total    -1.76
#
#                                             suggestion  \
# 0    Stand and stretch for one minute each hour or ...
# 1    Drink more water and take a light recovery wal...
# 2         Try going to bed 30 minutes earlier tonight.
# 3    Drink more water and take a light recovery wal...
# 4         Try going to bed 30 minutes earlier tonight.
# ..                                                 ...
# 162      Ensure adequate hydration and balanced meals.
# 163  Drink more water and take a light recovery wal...
# 164  Stand and stretch for one minute each hour or ...
# 165  Drink more water and take a light recovery wal...
# 166  Stand and stretch for one minute each hour or ...
#
#                                                because  priority  \
# 0    Low daily activity can lower energy and sleep ...        80
# 1    Elevated average heart rate can indicate dehyd...        90
# 2    Short sleep can increase stress and raise rest...        85
# 3    Elevated average heart rate can indicate dehyd...        90
# 4    Short sleep can increase stress and raise rest...        85
# ..                                                 ...       ...
# 162  Higher basal energy expenditure may reflect st...        70
# 163  Elevated average heart rate can indicate dehyd...        90
# 164  Low daily activity can lower energy and sleep ...        80
# 165  Elevated average heart rate can indicate dehyd...        90
# 166  Low daily activity can lower energy and sleep ...        80
#
#                                          source
# 0                    Apple Watch activity rings
# 1    Derived from Apple Watch heart rate trends
# 2                    Apple Watch sleep analysis
# 3    Derived from Apple Watch heart rate trends
# 4                    Apple Watch sleep analysis
# ..                                          ...
# 162              Apple Watch basal energy trend
# 163  Derived from Apple Watch heart rate trends
# 164                  Apple Watch activity rings
# 165  Derived from Apple Watch heart rate trends
# 166                  Apple Watch activity rings
#
# [167 rows x 9 columns]

# %%
results.tail(10)
# Out:
#            date rule_id           symptom              metric  z_value  \
# 157  2025-10-09   R1001       cardio_load             hr_mean     1.19
# 158  2025-10-11   R1004  metabolic_energy  basal_energy_total     1.26
# 159  2025-10-13   R1001       cardio_load             hr_mean     1.72
# 160  2025-10-14   R1002      low_activity        effort_total    -1.15
# 161  2025-10-16   R1001       cardio_load             hr_mean     1.32
# 162  2025-10-16   R1004  metabolic_energy  basal_energy_total     1.03
# 163  2025-10-18   R1001       cardio_load             hr_mean     3.33
# 164  2025-10-24   R1002      low_activity        effort_total    -1.09
# 165  2025-10-26   R1001       cardio_load             hr_mean     2.04
# 166  2025-10-27   R1002      low_activity        effort_total    -1.76
#
#                                             suggestion  \
# 157  Drink more water and take a light recovery wal...
# 158      Ensure adequate hydration and balanced meals.
# 159  Drink more water and take a light recovery wal...
# 160  Stand and stretch for one minute each hour or ...
# 161  Drink more water and take a light recovery wal...
# 162      Ensure adequate hydration and balanced meals.
# 163  Drink more water and take a light recovery wal...
# 164  Stand and stretch for one minute each hour or ...
# 165  Drink more water and take a light recovery wal...
# 166  Stand and stretch for one minute each hour or ...
#
#                                                because  priority  \
# 157  Elevated average heart rate can indicate dehyd...        90
# 158  Higher basal energy expenditure may reflect st...        70
# 159  Elevated average heart rate can indicate dehyd...        90
# 160  Low daily activity can lower energy and sleep ...        80
# 161  Elevated average heart rate can indicate dehyd...        90
# 162  Higher basal energy expenditure may reflect st...        70
# 163  Elevated average heart rate can indicate dehyd...        90
# 164  Low daily activity can lower energy and sleep ...        80
# 165  Elevated average heart rate can indicate dehyd...        90
# 166  Low daily activity can lower energy and sleep ...        80
#
#                                          source
# 157  Derived from Apple Watch heart rate trends
# 158              Apple Watch basal energy trend
# 159  Derived from Apple Watch heart rate trends
# 160                  Apple Watch activity rings
# 161  Derived from Apple Watch heart rate trends
# 162              Apple Watch basal energy trend
# 163  Derived from Apple Watch heart rate trends
# 164                  Apple Watch activity rings
# 165  Derived from Apple Watch heart rate trends
# 166                  Apple Watch activity rings
